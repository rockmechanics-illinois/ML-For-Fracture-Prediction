# %%
pip install -U tensorboardx
# Out:
# Collecting tensorboardx
#   Downloading tensorboardX-2.6.2.2-py2.py3-none-any.whl (101 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.7/101.7 kB 3.2 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from tensorboardx) (1.23.5)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorboardx) (23.1)
# Requirement already satisfied: protobuf>=3.20 in /usr/local/lib/python3.10/dist-packages (from tensorboardx) (3.20.3)
# Installing collected packages: tensorboardx
# Successfully installed tensorboardx-2.6.2.2

# %%
pip install ray
# Out:
# Collecting ray
#   Downloading ray-2.6.3-cp310-cp310-manylinux2014_x86_64.whl (56.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.9/56.9 MB 13.0 MB/s eta 0:00:00
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.10/dist-packages (from ray) (8.1.7)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from ray) (3.12.2)
# Requirement already satisfied: jsonschema in /usr/local/lib/python3.10/dist-packages (from ray) (4.19.0)
# Requirement already satisfied: msgpack<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from ray) (1.0.5)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from ray) (23.1)
# Requirement already satisfied: protobuf!=3.19.5,>=3.15.3 in /usr/local/lib/python3.10/dist-packages (from ray) (3.20.3)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from ray) (6.0.1)
# Requirement already satisfied: aiosignal in /usr/local/lib/python3.10/dist-packages (from ray) (1.3.1)
# Requirement already satisfied: frozenlist in /usr/local/lib/python3.10/dist-packages (from ray) (1.4.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from ray) (2.31.0)
# Requirement already satisfied: grpcio>=1.42.0 in /usr/local/lib/python3.10/dist-packages (from ray) (1.57.0)
# Requirement already satisfied: numpy>=1.19.3 in /usr/local/lib/python3.10/dist-packages (from ray) (1.23.5)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema->ray) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema->ray) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema->ray) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema->ray) (0.9.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->ray) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->ray) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->ray) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->ray) (2023.7.22)
# Installing collected packages: ray
# Successfully installed ray-2.6.3

# %%
pip install xgboost
# Out:
# Requirement already satisfied: xgboost in /usr/local/lib/python3.10/dist-packages (1.7.6)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from xgboost) (1.23.5)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from xgboost) (1.10.1)

# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestClassifier, RandomForestRegressor
from sklearn.metrics import accuracy_score, mean_squared_error, mean_absolute_error, f1_score
from sklearn.model_selection import train_test_split, GridSearchCV, RandomizedSearchCV, cross_val_score, KFold, cross_validate
import xgboost as xgb
from xgboost.sklearn import XGBClassifier
from random import randint, uniform

import ray
from ray import tune
from ray.tune.schedulers import ASHAScheduler

#import xgboost_ray as xgb_ray
from ray.tune.integration.xgboost import TuneReportCheckpointCallback
from ray.air import session

# %% [markdown]
# Define Wells That Will Be Used (Keep consistent with Data Import and Preprocessing Notebooks)

# %%
wells = ["CCS1", "VW1"]

# %% [markdown]
# Retrieve Data and Labels

# %%
datalogs = {}
labels = {}
datasets = {}
datalogs_path = "/content/drive/MyDrive/REU Project/Norm CSV Files/norm_"
labels_path = "/content/drive/MyDrive/REU Project/FMI LOGS/labels/label_"
for well in wells:
  datalogs_df = pd.read_csv(datalogs_path + well + ".csv")
  labels_df = pd.read_csv(labels_path + well + ".csv")

  datalogs_df = datalogs_df.drop(columns=["FORM"], axis=1)

  datalogs[well] = datalogs_df
  labels[well] = labels_df

  dataset = pd.merge(datalogs_df, labels_df, on='DEPT')
  datasets[well] = dataset

#shuffle order of test and training datasets for better results
VW1_dataset = datasets["VW1"].sample(frac=1)
CCS1_dataset = datasets["CCS1"].sample(frac=1)

#separate into train and test data
X_train = VW1_dataset.drop(columns=["HAS_FRAC"]).values
X_test = CCS1_dataset.drop(columns=["HAS_FRAC"]).values
y_train = VW1_dataset["HAS_FRAC"].values
y_test = CCS1_dataset["HAS_FRAC"].values

#get rid of depth for ML algo
X_train_nod = X_train[:, 1:]
X_test_nod = X_test[:, 1:]

# %% [markdown]
# Run random forest with randomly chosen hyperparameters for comparison

# %%
#print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)

#make random forest and run it
rfc = RandomForestClassifier(n_estimators=100,
                             min_samples_split=2,
                             min_samples_leaf=1,
                             max_features=30,
                             max_depth=10,
                             bootstrap=True,
                             random_state=0)
rfc.fit(X_train_nod, y_train)
y_pred = rfc.predict(X_test_nod)

print("Testing Accuracy Score:", accuracy_score(y_test, y_pred))
print("Testing F1 Score:", f1_score(y_test, y_pred))
# Out:
# Testing Accuracy Score: 0.7434194925302348
# Testing F1 Score: 0.10132890365448503

# %% [markdown]
# Make random forest and use random search to find best hyperparameters

# %%
param_grid = {
    "n_estimators": [20, 40, 60, 80, 100, 120, 140, 160, 180],
    "max_depth": [5, 10, 50, 100, 110],
    "max_features": [5, 10 , 15, 20, 25, 30],
    "min_samples_leaf": [1,2,3,4,5,6],
    "min_samples_split": [2,4,6,8,10,12,14]
}

rand_search = RandomizedSearchCV(RandomForestClassifier(),
                                 param_grid,
                                 n_iter=10,
                                 cv=5,
                                 verbose=1,
                                 n_jobs=-1)

rand_search.fit(X_train_nod, y_train)
y_pred = rand_search.predict(X_test_nod)
print(rand_search.best_params_)
print("Testing Accuracy Score:", accuracy_score(y_test, y_pred))
print("Testing F1 Score:", f1_score(y_test, y_pred))
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# {'n_estimators': 40, 'min_samples_split': 2, 'min_samples_leaf': 2, 'max_features': 10, 'max_depth': 100}
# Testing Accuracy Score: 0.7868152715200379
# Testing F1 Score: 0.16372093023255815

# %% [markdown]
# Make XGBoost and implement random search hyperparameter tuning

# %%
#convert Random Forest classifier to XGBoost Format
dtrain = xgb.DMatrix(X_train_nod, label=y_train)

#set grid for hyperparameter tuning
neg_class_count = len(y_train) - np.sum(y_train)
pos_class_count = np.sum(y_train)
hyperparameter_grid = {
    'max_depth': [5, 10, 50, 100, 110],
    'learning_rate': [0.001, 0.01, 0.05, 0.1, 0.15, 0.2],
    'subsample' :  [0.2, 0.5, 0.8, 0.9, 1.0], #fraction of training samples used for training each tree
    'colsample_bytree' : [0.2, 0.5, 0.8, 0.9, 1.0], #fraction of features used for training each tree
    'scale_pos_weight' : [1, neg_class_count / pos_class_count] #can assign higher weight to positive class
}

#train XGB classifier and use it to make predictions
xgb_classifier = xgb.XGBClassifier(objective = 'binary:logistic', seed=42)

#perform random search
rand_search = RandomizedSearchCV(estimator = xgb_classifier,
                                 param_distributions=hyperparameter_grid,
                                 n_iter=10,
                                 cv=5,
                                 verbose=1,
                                 n_jobs=-1,
                                 random_state=42)

rand_search.fit(X_train_nod, y_train)

#retrieve best model and its hyperparameters
best_classifier = rand_search.best_estimator_
best_params = rand_search.best_params_

y_pred = best_classifier.predict(X_test_nod)

print("Accuracy score:", accuracy_score(y_test, y_pred))
print("F1 score:", f1_score(y_test, y_pred))
print("Best hyperparameters", best_params)
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# Accuracy score: 0.8219113113587858
# F1 score: 0.1417142857142857
# Best hyperparameters {'subsample': 0.5, 'scale_pos_weight': 6.028119507908611, 'max_depth': 50, 'learning_rate': 0.15, 'colsample_bytree': 0.9}

# %% [markdown]
# Implement Raytune Hyperparameter Tuning (Shuts down models with low performing hyperparameters and focuses only on ones working well) on XGBoost model

# %%
def train_xgb(config):
    #calculate scale_pos_weight
    if config['scale_pos_weight'] == "ratio":
      neg_class_count = len(y_train) - np.sum(y_train)
      pos_class_count = np.sum(y_train)
      scale_pos_weight = neg_class_count / pos_class_count
    else:
      scale_pos_weight = config['scale_pos_weight']

    #convert Random Forest classifier to XGBoost Format
    dtrain = xgb.DMatrix(X_train_nod, label=y_train)

    hyperparameters = {
      'objective' : 'binary:logistic',
      'seed' : 42,
      'max_depth': config['max_depth'],
      'learning_rate': config['learning_rate'],
      'subsample' : config['subsample'], #fraction of training samples used for training each tree
      'colsample_bytree' : config['colsample_bytree'], #fraction of features used for training each tree
      'min_child_weight' : config['min_child_weight'],
      'reg_alpha' : config['reg_alpha'],
      'reg_lambda' : config['reg_lambda'],
      'scale_pos_weight' : scale_pos_weight #can assign higher weight to positive class
    }

    #train XGB classifier and use it to make predictions
    xgb_classifier = XGBClassifier(**hyperparameters)
    xgb_classifier.fit(X_train_nod, y_train)

    y_pred = xgb_classifier.predict(X_test_nod)

    f1 = f1_score(y_test, y_pred)
    tune.report(mean_f1=f1)

#Configure Raytune
ray.shutdown() #in case it didn't shut down right last time
ray.init()

scheduler = ASHAScheduler( #works well to gradually elimiate bad performing configurations
    metric="mean_f1",
    mode="max",
    max_t = 100
)

#run analysis
analysis = tune.run(
    train_xgb,
    num_samples = 500, #number of times to sample from hyperparameter space
    config={
            'max_depth': tune.choice([5, 25, 50, 75, 100, 125]),
            'learning_rate': tune.loguniform(0.001, 0.1),
            'subsample' :  tune.uniform(0.2, 1.0), #fraction of training samples used for training each tree
            'colsample_bytree' : tune.uniform(0.2, 1.0), #fraction of features used for training each tree
            'min_child_weight' : tune.uniform(2, 10),
            'reg_alpha' : tune.uniform(0, 1),
            'reg_lambda' : tune.uniform(0, 1),
            'scale_pos_weight' : tune.choice([1, "ratio"]), #can assign higher weight to positive class
    },
    scheduler=scheduler,
    verbose=1
)

#get best hyperparameters and accuracy
best_trial = analysis.get_best_trial("mean_f1", "max")
best_hyperparameters = best_trial.config
best_f1 = best_trial.last_result["mean_f1"]
print("Best configuration:", best_hyperparameters)
print("best f1:", best_f1)
# Out:
# 2023-08-22 02:44:48,987	INFO worker.py:1621 -- Started a local Ray instance.
# 2023-08-22 02:44:50,660	INFO tune.py:666 -- [output] This will use the new output engine with verbosity 1. To disable the new output and use the legacy output engine, set the environment variable RAY_AIR_NEW_OUTPUT=0. For more information, please see https://github.com/ray-project/ray/issues/36949
# Streaming output truncated to the last 5000 lines.
# +------------------------------------------------+
# | time_this_iter_s                       0.58135 |
# | time_total_s                           0.58135 |
# | training_iteration                           1 |
# | mean_f1                                0.16561 |
# +------------------------------------------------+
#
# Trial train_xgb_dd946_00318 started with configuration:
# +------------------------------------------------+
# | Trial train_xgb_dd946_00318 config             |
# +------------------------------------------------+
# | colsample_bytree                       0.22837 |
# | learning_rate                          0.01271 |
# | max_depth                                  125 |
# | min_child_weight                       3.18118 |
# | reg_alpha                              0.49233 |
# | reg_lambda                             0.57186 |
# | scale_pos_weight                         ratio |
# | subsample                              0.36757 |
# +------------------------------------------------+
#
# Trial train_xgb_dd946_00316 completed after 1 iterations at 2023-08-22 02:49:29. Total running time: 4min 34s
# +------------------------------------------------+
# | Trial train_xgb_dd946_00316 result             |
# +------------------------------------------------+
# | time_this_iter_s                       2.43118 |
# | time_total_s                           2.43118 |
# | training_iteration                           1 |
# | mean_f1                                0.36446 |
# +------------------------------------------------+
#
# Trial train_xgb_dd946_00319 started with configuration:
# +------------------------------------------------+
# | Trial train_xgb_dd946_00319 config             |
# +------------------------------------------------+
# | colsample_bytree                         0.883 |
# | learning_rate                          0.00441 |
# | max_depth                                  100 |
# | min_child_weight                       5.17925 |
# | reg_alpha                                0.847 |
# | reg_lambda                             0.81175 |
# | scale_pos_weight                         ratio |
# | subsample                              0.64327 |
# +------------------------------------------------+
#
# Trial train_xgb_dd946_00318 completed after 1 iterations at 2023-08-22 02:49:30. Total running time: 4min 35s
# +------------------------------------------------+
# | Trial train_xgb_dd946_00318 result             |
# +------------------------------------------------+
# | time_this_iter_s                       1.25489 |
# | time_total_s                           1.25489 |
# | training_iteration                           1 |
# | mean_f1                                0.16244 |
# +------------------------------------------------+
#
# Trial train_xgb_dd946_00320 started with configuration:
# +------------------------------------------------+
# | Trial train_xgb_dd946_00320 config             |
# +------------------------------------------------+
# | colsample_bytree                       0.43632 |
# | learning_rate                          0.00117 |
# | max_depth                                   50 |
# | min_child_weight                       2.88941 |
# | reg_alpha                              0.35987 |
# | reg_lambda                             0.72325 |
# | scale_pos_weight                             1 |
# | subsample                              0.94743 |
# +------------------------------------------------+
#
# Trial train_xgb_dd946_00320 completed after 1 iterations at 2023-08-22 02:49:33. Total running time: 4min 37s
# +------------------------------------------------+
# | Trial train_xgb_dd946_00320 result             |
# +------------------------------------------------+
# | time_this_iter_s                       2.80294 |
# | time_total_s                           2.80294 |
# | training_iteration                           1 |
# | mean_f1                                0.07809 |
# +------------------------------------------------+
#
# Trial train_xgb_dd946_00321 started with configuration:
# +------------------------------------------------+
# | Trial train_xgb_dd946_00321 config             |
# +------------------------------------------------+
# | colsample_bytree                       0.62892 |
# | learning_rate                          0.00701 |
# | max_depth                                   25 |
# | min_child_weight                       6.37557 |
# | reg_alpha                              0.28837 |
# | reg_lambda                             0.92389 |
# | scale_pos_weight                             1 |
# | subsample                              0.82476 |
# +------------------------------------------------+
#
# Trial train_xgb_dd946_00319 completed after 1 iterations at 2023-08-22 02:49:34. Total running time: 4min 38s
# +------------------------------------------------+
# | Trial train_xgb_dd946_00319 result             |
# +------------------------------------------------+
# | time_this_iter_s                       4.38298 |
# | time_total_s                           4.38298 |
# | training_iteration                           1 |
# | mean_f1                                0.34073 |
# +------------------------------------------------+
#
# Trial train_xgb_dd946_00322 started with configuration:
# +------------------------------------------------+
# | Trial train_xgb_dd946_00322 config             |
# +------------------------------------------------+
# | colsample_bytree                       0.34341 |
# | learning_rate                          0.01751 |
# | max_depth                                  125 |
# | min_child_weight                       4.30683 |
# | reg_alpha                              0.87839 |
# | reg_lambda                             0.94017 |
# | scale_pos_weight                         ratio |
# | subsample                              0.22238 |
# +------------------------------------------------+
#
# Trial train_xgb_dd946_00322 completed after 1 iterations at 2023-08-22 02:49:35. Total running time: 4min 40s
# +------------------------------------------------+
# | Trial train_xgb_dd946_00322 result             |
# +------------------------------------------------+
# | time_this_iter_s                       1.11348 |
# | time_total_s                           1.11348 |
# | training_iteration                           1 |
# | mean_f1                                0.31703 |
# +------------------------------------------------+
#
# Trial train_xgb_dd946_00323 started with configuration:
# +------------------------------------------------+
# | Trial train_xgb_dd946_00323 config             |
# +------------------------------------------------+
# | colsample_bytree                       0.54746 |
# | learning_rate                          0.00113 |
# | max_depth                                  100 |
# | min_child_weight                        3.6216 |
# | reg_alpha                              0.14079 |
# | reg_lambda                             0.08385 |
# | scale_pos_weight                             1 |
# | subsample                              0.48252 |
# +------------------------------------------------+
#
# Trial train_xgb_dd946_00321 completed after 1 iterations at 2023-08-22 02:49:35. Total running time: 4min 40s
# +------------------------------------------------+
# | Trial train_xgb_dd946_00321 result             |
# +------------------------------------------------+
# | time_this_iter_s                       2.66779 |
# | time_total_s                           2.66779 |
# | training_iteration                           1 |
# | mean_f1                                0.09789 |
# +------------------------------------------------+
#
# Trial train_xgb_dd946_00324 started with configuration:
# +------------------------------------------------+
# | Trial train_xgb_dd946_00324 config             |
# +------------------------------------------------+
# | colsample_bytree                       0.86253 |
# | learning_rate                          0.00111 |
# | max_depth                                   50 |
# | min_child_weight                       4.45679 |
# | reg_alpha                              0.56472 |
# | reg_lambda                             0.92649 |
# | scale_pos_weight                         ratio |
# | subsample                              0.48232 |
# +------------------------------------------------+
#
# Trial train_xgb_dd946_00323 completed after 1 iterations at 2023-08-22 02:49:36. Total running time: 4min 41s
# +------------------------------------------------+
# | Trial train_xgb_dd946_00323 result             |
# +------------------------------------------------+
# | time_this_iter_s                       1.49626 |
# | time_total_s                           1.49626 |
# | training_iteration                           1 |
# | mean_f1                                0.11307 |
# +------------------------------------------------+
#
# Trial train_xgb_dd946_00325 started with configuration:
# +------------------------------------------------+
# | Trial train_xgb_dd946_00325 config             |
# +------------------------------------------------+
# | colsample_bytree                       0.20021 |
# | learning_rate                          0.00115 |
# | max_depth                                   50 |
# | min_child_weight                       7.79095 |
# | reg_alpha                              0.39734 |
# | reg_lambda                             0.23687 |
# | scale_pos_weight                             1 |
# | subsample                              0.70905 |
# +------------------------------------------------+
#
# Trial train_xgb_dd946_00325 completed after 1 iterations at 2023-08-22 02:49:37. Total running time: 4min 42s
# +------------------------------------------------+
# | Trial train_xgb_dd946_00325 result             |
# +------------------------------------------------+
# | time_this_iter_s                       0.69283 |
# | time_total_s                           0.69283 |
# | training_iteration                           1 |
# | mean_f1                                0.02053 |
# +------------------------------------------------+
#
# Trial train_xgb_dd946_00326 started with configuration:
# +------------------------------------------------+
# | Trial train_xgb_dd946_00326 config             |
# +------------------------------------------------+
# | colsample_bytree                       0.23677 |
# | learning_rate                          0.01568 |
# | max_depth                                  100 |
# | min_child_weight                       8.04619 |
# | reg_alpha                              0.71408 |
# | reg_lambda                             0.12309 |
# | scale_pos_weight                         ratio |
# | subsample                              0.93692 |
# +------------------------------------------------+
#
# Trial train_xgb_dd946_00324 completed after 1 iterations at 2023-08-22 02:49:38. Total running time: 4min 42s
# +------------------------------------------------+
# | Trial train_xgb_dd946_00324 result             |
# +------------------------------------------------+
# | time_this_iter_s                       2.19667 |
# | time_total_s                           2.19667 |
# | training_iteration                           1 |
# | mean_f1                                0.33856 |
# +------------------------------------------------+
#
# Trial train_xgb_dd946_00327 started with configuration:
# +------------------------------------------------+
# | Trial train_xgb_dd946_00327 config             |
# +------------------------------------------------+
# | colsample_bytree                       0.85288 |
# | learning_rate                          0.06577 |
# | max_depth                                   25 |
# | min_child_weight                       8.31515 |
# | reg_alpha                              0.11079 |
# | reg_lambda                             0.25666 |
# | scale_pos_weight                             1 |
# | subsample                              0.98214 |
# +------------------------------------------------+
#
# Trial train_xgb_dd946_00326 completed after 1 iterations at 2023-08-22 02:49:38. Total running time: 4min 43s
# +------------------------------------------------+
# | Trial train_xgb_dd946_00326 result             |
# +------------------------------------------------+
# | time_this_iter_s                        1.3078 |
# | time_total_s                            1.3078 |
# | training_iteration                           1 |
# | mean_f1                                0.26359 |
# +------------------------------------------------+
#
# Trial train_xgb_dd946_00328 started with configuration:
# +------------------------------------------------+
# | Trial train_xgb_dd946_00328 config             |
# +------------------------------------------------+
# | colsample_bytree                       0.23208 |
# | learning_rate                          0.04331 |
# | max_depth                                   25 |
# | min_child_weight                       9.07766 |
# | reg_alpha                              0.26941 |
# | reg_lambda                             0.25126 |
# | scale_pos_weight                             1 |
# | subsample                              0.60012 |
# +------------------------------------------------+
#
# Trial train_xgb_dd946_00328 completed after 1 iterations at 2023-08-22 02:49:39. Total running time: 4min 44s
# +------------------------------------------------+
# | Trial train_xgb_dd946_00328 result             |
# +------------------------------------------------+
# | time_this_iter_s                       0.62217 |
# | time_total_s                           0.62217 |
# | training_iteration                           1 |
# | mean_f1                                0.05591 |
# +------------------------------------------------+
#
# Trial train_xgb_dd946_00329 started with configuration:
# +------------------------------------------------+
# | Trial train_xgb_dd946_00329 config             |
# +------------------------------------------------+
# | colsample_bytree                       0.25751 |
# | learning_rate                          0.02254 |
# | max_depth                                    5 |
# | min_child_weight                       6.84109 |
# | reg_alpha                                0.451 |
# | reg_lambda                             0.10827 |
# | scale_pos_weight                         ratio |
# | subsample                               0.2936 |
# +------------------------------------------------+
#
# Trial train_xgb_dd946_00329 completed after 1 iterations at 2023-08-22 02:49:39. Total running time: 4min 44s
# +------------------------------------------------+
# | Trial train_xgb_dd946_00329 result             |
# +------------------------------------------------+
# | time_this_iter_s                       0.34119 |
# | time_total_s                           0.34119 |
# | training_iteration                           1 |
# | mean_f1                                0.33941 |
# +------------------------------------------------+
#
# Trial train_xgb_dd946_00330 started with configuration:
# +------------------------------------------------+
# | Trial train_xgb_dd946_00330 config             |
# +------------------------------------------------+
# | colsample_bytree                       0.91467 |
# | learning_rate                          0.00182 |
# | max_depth                                  125 |
# | min_child_weight                       6.65044 |
# | reg_alpha                              0.09585 |
# | reg_lambda                              0.8959 |
# | scale_pos_weight                         ratio |
# | subsample                               0.3492 |
# +------------------------------------------------+
#
# Trial train_xgb_dd946_00327 completed after 1 iterations at 2023-08-22 02:49:40. Total running time: 4min 45s
# +------------------------------------------------+
# | Trial train_xgb_dd946_00327 result             |
# +------------------------------------------------+
# | time_this_iter_s                       2.45661 |
# | time_total_s                           2.45661 |
# | training_iteration                           1 |
# | mean_f1                                0.24442 |
# +------------------------------------------------+
#
# Trial train_xgb_dd946_00331 started with configuration:
# +------------------------------------------------+
# | Trial train_xgb_dd946_00331 config             |
# +------------------------------------------------+
# | colsample_bytree                       0.99064 |
# | learning_rate                          0.00109 |
# | max_depth                                  100 |
# | min_child_weight                       5.06032 |
# | reg_alpha                              0.26064 |
# | reg_lambda                              0.9873 |
# | scale_pos_weight                             1 |
# | subsample                              0.98886 |
# +------------------------------------------------+
#
# Trial train_xgb_dd946_00330 completed after 1 iterations at 2023-08-22 02:49:41. Total running time: 4min 46s
# +------------------------------------------------+
# | Trial train_xgb_dd946_00330 result             |
# +------------------------------------------------+
# | time_this_iter_s                       1.44122 |
# | time_total_s                           1.44122 |
# | training_iteration                           1 |
# | mean_f1                                0.30933 |
# +------------------------------------------------+
#
# Trial train_xgb_dd946_00332 started with configuration:
# +------------------------------------------------+
# | Trial train_xgb_dd946_00332 config             |
# +------------------------------------------------+
# | colsample_bytree                       0.36887 |
# | learning_rate                          0.00182 |
# | max_depth                                    5 |
# | min_child_weight                       9.41228 |
# | reg_alpha                              0.59297 |
# | reg_lambda                             0.73198 |
# | scale_pos_weight                             1 |
# | subsample                              0.49458 |
# +------------------------------------------------+
#
# Trial train_xgb_dd946_00332 completed after 1 iterations at 2023-08-22 02:49:41. Total running time: 4min 46s
# +------------------------------------------------+
# | Trial train_xgb_dd946_00332 result             |
# +------------------------------------------------+
# | time_this_iter_s                       0.49047 |
# | time_total_s                           0.49047 |
# | training_iteration                           1 |
# | mean_f1                                0.05759 |
# +------------------------------------------------+
#
# Trial train_xgb_dd946_00333 started with configuration:
# +------------------------------------------------+
# | Trial train_xgb_dd946_00333 config             |
# +------------------------------------------------+
# | colsample_bytree                       0.84972 |
# | learning_rate                          0.08394 |
# | max_depth                                   75 |
# | min_child_weight                       3.89739 |
# | reg_alpha                              0.33205 |
# | reg_lambda                             0.02885 |
# | scale_pos_weight                         ratio |
# | subsample                              0.55119 |
# +------------------------------------------------+
#
# Trial train_xgb_dd946_00331 completed after 1 iterations at 2023-08-22 02:49:43. Total running time: 4min 48s
# +------------------------------------------------+
# | Trial train_xgb_dd946_00331 result             |
# +------------------------------------------------+
# | time_this_iter_s                       2.62702 |
# | time_total_s                           2.62702 |
# | training_iteration                           1 |
# | mean_f1                                0.25746 |
# +------------------------------------------------+
#
# Trial train_xgb_dd946_00334 started with configuration:
# +------------------------------------------------+
# | Trial train_xgb_dd946_00334 config             |
# +------------------------------------------------+
# | colsample_bytree                       0.65275 |
# | learning_rate                          0.00364 |
# | max_depth                                  100 |
# | min_child_weight                       3.85682 |
# | reg_alpha                              0.96088 |
# | reg_lambda                             0.07069 |
# | scale_pos_weight                         ratio |
# | subsample                              0.93645 |
# +------------------------------------------------+
#
# Trial train_xgb_dd946_00333 completed after 1 iterations at 2023-08-22 02:49:44. Total running time: 4min 48s
# +------------------------------------------------+
# | Trial train_xgb_dd946_00333 result             |
# +------------------------------------------------+
# | time_this_iter_s                       2.07764 |
# | time_total_s                           2.07764 |
# | training_iteration                           1 |
# | mean_f1                                0.21782 |
# +------------------------------------------------+
#
# Trial train_xgb_dd946_00335 started with configuration:
# +------------------------------------------------+
# | Trial train_xgb_dd946_00335 config             |
# +------------------------------------------------+
# | colsample_bytree                       0.67634 |
# | learning_rate                          0.00187 |
# | max_depth                                  100 |
# | min_child_weight                       6.62904 |
# | reg_alpha                              0.51603 |
# | reg_lambda                             0.31448 |
# | scale_pos_weight                         ratio |
# | subsample                              0.70224 |
# +------------------------------------------------+
#
# Trial train_xgb_dd946_00335 completed after 1 iterations at 2023-08-22 02:49:47. Total running time: 4min 52s
# +------------------------------------------------+
# | Trial train_xgb_dd946_00335 result             |
# +------------------------------------------------+
# | time_this_iter_s                       3.57203 |
# | time_total_s                           3.57203 |
# | training_iteration                           1 |
# | mean_f1                                0.34943 |
# +------------------------------------------------+
#
# Trial train_xgb_dd946_00336 started with configuration:
# +------------------------------------------------+
# | Trial train_xgb_dd946_00336 config             |
# +------------------------------------------------+
# | colsample_bytree                       0.62382 |
# | learning_rate                          0.01722 |
# | max_depth                                   25 |
# | min_child_weight                       9.63825 |
# | reg_alpha                              0.40174 |
# | reg_lambda                             0.57969 |
# | scale_pos_weight                             1 |
# | subsample                              0.75603 |
# +------------------------------------------------+
#
# Trial train_xgb_dd946_00334 completed after 1 iterations at 2023-08-22 02:49:47. Total running time: 4min 52s
# +------------------------------------------------+
# | Trial train_xgb_dd946_00334 result             |
# +------------------------------------------------+
# | time_this_iter_s                       4.40536 |
# | time_total_s                           4.40536 |
# | training_iteration                           1 |
# | mean_f1                                0.34742 |
# +------------------------------------------------+
#
# Trial train_xgb_dd946_00337 started with configuration:
# +------------------------------------------------+
# | Trial train_xgb_dd946_00337 config             |
# +------------------------------------------------+
# | colsample_bytree                       0.95827 |
# | learning_rate                          0.00362 |
# | max_depth                                  100 |
# | min_child_weight                       3.56876 |
# | reg_alpha                              0.64318 |
# | reg_lambda                             0.01527 |
# | scale_pos_weight                             1 |
# | subsample                               0.9046 |
# +------------------------------------------------+
#
# Trial train_xgb_dd946_00336 completed after 1 iterations at 2023-08-22 02:49:50. Total running time: 4min 55s
# +------------------------------------------------+
# | Trial train_xgb_dd946_00336 result             |
# +------------------------------------------------+
# | time_this_iter_s                       2.72438 |
# | time_total_s                           2.72438 |
# | training_iteration                           1 |
# | mean_f1                                0.10023 |
# +------------------------------------------------+
#
# Trial train_xgb_dd946_00338 started with configuration:
# +------------------------------------------------+
# | Trial train_xgb_dd946_00338 config             |
# +------------------------------------------------+
# | colsample_bytree                       0.33679 |
# | learning_rate                          0.00985 |
# | max_depth                                   25 |
# | min_child_weight                         4.999 |
# | reg_alpha                              0.00747 |
# | reg_lambda                             0.44977 |
# | scale_pos_weight                             1 |
# | subsample                              0.71545 |
# +------------------------------------------------+
#
# Trial train_xgb_dd946_00338 completed after 1 iterations at 2023-08-22 02:49:52. Total running time: 4min 57s
# +------------------------------------------------+
# | Trial train_xgb_dd946_00338 result             |
# +------------------------------------------------+
# | time_this_iter_s                       2.32374 |
# | time_total_s                           2.32374 |
# | training_iteration                           1 |
# | mean_f1                                0.04802 |
# +------------------------------------------------+
#
# Trial train_xgb_dd946_00339 started with configuration:
# +------------------------------------------------+
# | Trial train_xgb_dd946_00339 config             |
# +------------------------------------------------+
# | colsample_bytree                       0.70149 |
# | learning_rate                          0.00444 |
# | max_depth                                   50 |
# | min_child_weight                       2.60413 |
# | reg_alpha                              0.94643 |
# | reg_lambda                             0.19108 |
# | scale_pos_weight                         ratio |
# | subsample                              0.91194 |
# +------------------------------------------------+
#
# Trial train_xgb_dd946_00337 completed after 1 iterations at 2023-08-22 02:49:53. Total running time: 4min 58s
# +------------------------------------------------+
# | Trial train_xgb_dd946_00337 result             |
# +------------------------------------------------+
# | time_this_iter_s                       5.67591 |
# | time_total_s                           5.67591 |
# | training_iteration                           1 |
# | mean_f1                                0.28263 |
# +------------------------------------------------+
#
# Trial train_xgb_dd946_00340 started with configuration:
# +------------------------------------------------+
# | Trial train_xgb_dd946_00340 config             |
# +------------------------------------------------+
# | colsample_bytree                       0.74873 |
# | learning_rate                          0.01049 |
# | max_depth                                    5 |
# | min_child_weight                       9.33748 |
# | reg_alpha                              0.11803 |
# | reg_lambda                             0.68651 |
# | scale_pos_weight                             1 |
# | subsample                              0.24148 |
# +------------------------------------------------+
#
# Trial train_xgb_dd946_00340 completed after 1 iterations at 2023-08-22 02:49:54. Total running time: 4min 59s
# +------------------------------------------------+
# | Trial train_xgb_dd946_00340 result             |
# +------------------------------------------------+
# | time_this_iter_s                       0.93151 |
# | time_total_s                           0.93151 |
# | training_iteration                           1 |
# | mean_f1                                 0.1612 |
# +------------------------------------------------+
#
# Trial train_xgb_dd946_00341 started with configuration:
# +------------------------------------------------+
# | Trial train_xgb_dd946_00341 config             |
# +------------------------------------------------+
# | colsample_bytree                       0.35619 |
# | learning_rate                          0.00331 |
# | max_depth                                   25 |
# | min_child_weight                       5.00697 |
# | reg_alpha                              0.03843 |
# | reg_lambda                             0.85028 |
# | scale_pos_weight                         ratio |
# | subsample                               0.8089 |
# +------------------------------------------------+
#
# Trial train_xgb_dd946_00341 completed after 1 iterations at 2023-08-22 02:49:55. Total running time: 5min 0s
# +------------------------------------------------+
# | Trial train_xgb_dd946_00341 result             |
# +------------------------------------------------+
# | time_this_iter_s                       1.43843 |
# | time_total_s                           1.43843 |
# | training_iteration                           1 |
# | mean_f1                                0.29202 |
# +------------------------------------------------+
#
# Trial train_xgb_dd946_00342 started with configuration:
# +------------------------------------------------+
# | Trial train_xgb_dd946_00342 config             |
# +------------------------------------------------+
# | colsample_bytree                       0.49339 |
# | learning_rate                          0.01486 |
# | max_depth                                   25 |
# | min_child_weight                       2.67434 |
# | reg_alpha                              0.26021 |
# | reg_lambda                             0.13565 |
# | scale_pos_weight                         ratio |
# | subsample                              0.72336 |
# +------------------------------------------------+
#
# Trial status: 341 TERMINATED | 2 RUNNING | 16 PENDING
# Current time: 2023-08-22 02:49:56. Total running time: 5min 1s
# Logical resource usage: 2.0/2 CPUs, 0/0 GPUs
# +----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | Trial name              status         max_depth     learning_rate     subsample     colsample_bytree     min_child_weight     reg_alpha     reg_lambda   scale_pos_weight       iter     total time (s)     mean_f1 |
# +----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | train_xgb_dd946_00339   RUNNING               50        0.00444471      0.911937             0.701486              2.60413      0.94643        0.19108    ratio                                                      |
# | train_xgb_dd946_00342   RUNNING               25        0.0148575       0.723358             0.493389              2.67434      0.260205       0.135652   ratio                                                      |
# | train_xgb_dd946_00000   TERMINATED            25        0.00110464      0.528839             0.464467              9.83134      0.305138       0.540231   ratio                     1           1.23801    0.341518  |
# | train_xgb_dd946_00001   TERMINATED             5        0.0543066       0.279221             0.668022              2.095        0.954987       0.259059   1                         1           0.645849   0.128746  |
# | train_xgb_dd946_00002   TERMINATED            50        0.0370771       0.769011             0.470069              9.95974      0.369429       0.51499    1                         1           1.11128    0.0838323 |
# | train_xgb_dd946_00003   TERMINATED           100        0.00605796      0.800935             0.467193              3.62357      0.828528       0.306993   ratio                     1           1.86605    0.339298  |
# | train_xgb_dd946_00004   TERMINATED           100        0.0202623       0.461953             0.857492              4.76755      0.643435       0.648279   ratio                     1           1.80013    0.285714  |
# | train_xgb_dd946_00343   PENDING               75        0.0248884       0.72362              0.980229              9.90436      0.817201       0.160223   ratio                                                      |
# | train_xgb_dd946_00344   PENDING              100        0.00353704      0.494682             0.973613              4.25537      0.929413       0.708731   1                                                          |
# | train_xgb_dd946_00345   PENDING              100        0.0417649       0.217257             0.895556              8.4697       0.579506       0.427419   ratio                                                      |
# | train_xgb_dd946_00346   PENDING              100        0.0192949       0.477293             0.7814                3.43659      0.363816       0.555082   ratio                                                      |
# | train_xgb_dd946_00347   PENDING                5        0.0546045       0.356085             0.922462              9.67437      0.459257       0.407443   ratio                                                      |
# +----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# 336 more TERMINATED, 11 more PENDING
#
# Trial train_xgb_dd946_00339 completed after 1 iterations at 2023-08-22 02:49:56. Total running time: 5min 1s
# +------------------------------------------------+
# | Trial train_xgb_dd946_00339 result             |
# +------------------------------------------------+
# | time_this_iter_s                       3.63263 |
# | time_total_s                           3.63263 |
# | training_iteration                           1 |
# | mean_f1                                0.35766 |
# +------------------------------------------------+
#
# Trial train_xgb_dd946_00343 started with configuration:
# +------------------------------------------------+
# | Trial train_xgb_dd946_00343 config             |
# +------------------------------------------------+
# | colsample_bytree                       0.98023 |
# | learning_rate                          0.02489 |
# | max_depth                                   75 |
# | min_child_weight                       9.90436 |
# | reg_alpha                               0.8172 |
# | reg_lambda                             0.16022 |
# | scale_pos_weight                         ratio |
# | subsample                              0.72362 |
# +------------------------------------------------+
#
# Trial train_xgb_dd946_00342 completed after 1 iterations at 2023-08-22 02:49:57. Total running time: 5min 2s
# +-----------------------------------------------+
# | Trial train_xgb_dd946_00342 result            |
# +-----------------------------------------------+
# | time_this_iter_s                       1.8876 |
# | time_total_s                           1.8876 |
# | training_iteration                          1 |
# | mean_f1                                0.3057 |
# +-----------------------------------------------+
#
# Trial train_xgb_dd946_00344 started with configuration:
# +------------------------------------------------+
# | Trial train_xgb_dd946_00344 config             |
# +------------------------------------------------+
# | colsample_bytree                       0.97361 |
# | learning_rate                          0.00354 |
# | max_depth                                  100 |
# | min_child_weight                       4.25537 |
# | reg_alpha                              0.92941 |
# | reg_lambda                             0.70873 |
# | scale_pos_weight                             1 |
# | subsample                              0.49468 |
# +------------------------------------------------+
#
# Trial train_xgb_dd946_00343 completed after 1 iterations at 2023-08-22 02:49:59. Total running time: 5min 3s
# +------------------------------------------------+
# | Trial train_xgb_dd946_00343 result             |
# +------------------------------------------------+
# | time_this_iter_s                       2.55122 |
# | time_total_s                           2.55122 |
# | training_iteration                           1 |
# | mean_f1                                0.32361 |
# +------------------------------------------------+
#
# Trial train_xgb_dd946_00345 started with configuration:
# +------------------------------------------------+
# | Trial train_xgb_dd946_00345 config             |
# +------------------------------------------------+
# | colsample_bytree                       0.89556 |
# | learning_rate                          0.04176 |
# | max_depth                                  100 |
# | min_child_weight                        8.4697 |
# | reg_alpha                              0.57951 |
# | reg_lambda                             0.42742 |
# | scale_pos_weight                         ratio |
# | subsample                              0.21726 |
# +------------------------------------------------+
#
# Trial train_xgb_dd946_00344 completed after 1 iterations at 2023-08-22 02:49:59. Total running time: 5min 3s
# +------------------------------------------------+
# | Trial train_xgb_dd946_00344 result             |
# +------------------------------------------------+
# | time_this_iter_s                       1.45877 |
# | time_total_s                           1.45877 |
# | training_iteration                           1 |
# | mean_f1                                0.12059 |
# +------------------------------------------------+
#
# Trial train_xgb_dd946_00346 started with configuration:
# +------------------------------------------------+
# | Trial train_xgb_dd946_00346 config             |
# +------------------------------------------------+
# | colsample_bytree                        0.7814 |
# | learning_rate                          0.01929 |
# | max_depth                                  100 |
# | min_child_weight                       3.43659 |
# | reg_alpha                              0.36382 |
# | reg_lambda                             0.55508 |
# | scale_pos_weight                         ratio |
# | subsample                              0.47729 |
# +------------------------------------------------+
#
# Trial train_xgb_dd946_00345 completed after 1 iterations at 2023-08-22 02:49:59. Total running time: 5min 4s
# +------------------------------------------------+
# | Trial train_xgb_dd946_00345 result             |
# +------------------------------------------------+
# | time_this_iter_s                       0.87477 |
# | time_total_s                           0.87477 |
# | training_iteration                           1 |
# | mean_f1                                0.26035 |
# +------------------------------------------------+
#
# Trial train_xgb_dd946_00347 started with configuration:
# +------------------------------------------------+
# | Trial train_xgb_dd946_00347 config             |
# +------------------------------------------------+
# | colsample_bytree                       0.92246 |
# | learning_rate                           0.0546 |
# | max_depth                                    5 |
# | min_child_weight                       9.67437 |
# | reg_alpha                              0.45926 |
# | reg_lambda                             0.40744 |
# | scale_pos_weight                         ratio |
# | subsample                              0.35609 |
# +------------------------------------------------+
#
# Trial train_xgb_dd946_00347 completed after 1 iterations at 2023-08-22 02:50:00. Total running time: 5min 5s
# +------------------------------------------------+
# | Trial train_xgb_dd946_00347 result             |
# +------------------------------------------------+
# | time_this_iter_s                        0.8722 |
# | time_total_s                            0.8722 |
# | training_iteration                           1 |
# | mean_f1                                0.23184 |
# +------------------------------------------------+
#
# Trial train_xgb_dd946_00348 started with configuration:
# +------------------------------------------------+
# | Trial train_xgb_dd946_00348 config             |
# +------------------------------------------------+
# | colsample_bytree                       0.60739 |
# | learning_rate                          0.02793 |
# | max_depth                                  100 |
# | min_child_weight                       9.70461 |
# | reg_alpha                                0.817 |
# | reg_lambda                             0.81403 |
# | scale_pos_weight                             1 |
# | subsample                              0.41893 |
# +------------------------------------------------+
#
# Trial train_xgb_dd946_00346 completed after 1 iterations at 2023-08-22 02:50:01. Total running time: 5min 5s
# +------------------------------------------------+
# | Trial train_xgb_dd946_00346 result             |
# +------------------------------------------------+
# | time_this_iter_s                       1.91661 |
# | time_total_s                           1.91661 |
# | training_iteration                           1 |
# | mean_f1                                0.24805 |
# +------------------------------------------------+
#
# Trial train_xgb_dd946_00349 started with configuration:
# +------------------------------------------------+
# | Trial train_xgb_dd946_00349 config             |
# +------------------------------------------------+
# | colsample_bytree                        0.3303 |
# | learning_rate                          0.07999 |
# | max_depth                                    5 |
# | min_child_weight                       4.20679 |
# | reg_alpha                              0.29283 |
# | reg_lambda                             0.09274 |
# | scale_pos_weight                             1 |
# | subsample                              0.50774 |
# +------------------------------------------------+
#
# Trial train_xgb_dd946_00348 completed after 1 iterations at 2023-08-22 02:50:01. Total running time: 5min 6s
# +------------------------------------------------+
# | Trial train_xgb_dd946_00348 result             |
# +------------------------------------------------+
# | time_this_iter_s                       0.78001 |
# | time_total_s                           0.78001 |
# | training_iteration                           1 |
# | mean_f1                                0.10689 |
# +------------------------------------------------+
#
# Trial train_xgb_dd946_00350 started with configuration:
# +------------------------------------------------+
# | Trial train_xgb_dd946_00350 config             |
# +------------------------------------------------+
# | colsample_bytree                        0.6468 |
# | learning_rate                          0.01134 |
# | max_depth                                    5 |
# | min_child_weight                       9.19361 |
# | reg_alpha                              0.98886 |
# | reg_lambda                             0.20082 |
# | scale_pos_weight                             1 |
# | subsample                              0.64916 |
# +------------------------------------------------+
#
# Trial train_xgb_dd946_00349 completed after 1 iterations at 2023-08-22 02:50:01. Total running time: 5min 6s
# +------------------------------------------------+
# | Trial train_xgb_dd946_00349 result             |
# +------------------------------------------------+
# | time_this_iter_s                       0.48689 |
# | time_total_s                           0.48689 |
# | training_iteration                           1 |
# | mean_f1                                0.08948 |
# +------------------------------------------------+
#
# Trial train_xgb_dd946_00351 started with configuration:
# +------------------------------------------------+
# | Trial train_xgb_dd946_00351 config             |
# +------------------------------------------------+
# | colsample_bytree                       0.80295 |
# | learning_rate                          0.06816 |
# | max_depth                                   75 |
# | min_child_weight                       8.93774 |
# | reg_alpha                              0.40989 |
# | reg_lambda                             0.45023 |
# | scale_pos_weight                         ratio |
# | subsample                               0.8777 |
# +------------------------------------------------+
#
# Trial train_xgb_dd946_00350 completed after 1 iterations at 2023-08-22 02:50:02. Total running time: 5min 7s
# +------------------------------------------------+
# | Trial train_xgb_dd946_00350 result             |
# +------------------------------------------------+
# | time_this_iter_s                       0.86998 |
# | time_total_s                           0.86998 |
# | training_iteration                           1 |
# | mean_f1                                 0.1409 |
# +------------------------------------------------+
#
# Trial train_xgb_dd946_00352 started with configuration:
# +------------------------------------------------+
# | Trial train_xgb_dd946_00352 config             |
# +------------------------------------------------+
# | colsample_bytree                       0.33638 |
# | learning_rate                           0.0013 |
# | max_depth                                   75 |
# | min_child_weight                       6.61009 |
# | reg_alpha                              0.32916 |
# | reg_lambda                             0.62864 |
# | scale_pos_weight                         ratio |
# | subsample                               0.2693 |
# +------------------------------------------------+
#
# Trial train_xgb_dd946_00352 completed after 1 iterations at 2023-08-22 02:50:03. Total running time: 5min 7s
# +------------------------------------------------+
# | Trial train_xgb_dd946_00352 result             |
# +------------------------------------------------+
# | time_this_iter_s                       0.65977 |
# | time_total_s                           0.65977 |
# | training_iteration                           1 |
# | mean_f1                                0.31793 |
# +------------------------------------------------+
#
# Trial train_xgb_dd946_00353 started with configuration:
# +------------------------------------------------+
# | Trial train_xgb_dd946_00353 config             |
# +------------------------------------------------+
# | colsample_bytree                       0.31051 |
# | learning_rate                          0.00517 |
# | max_depth                                  100 |
# | min_child_weight                       8.39651 |
# | reg_alpha                              0.65078 |
# | reg_lambda                             0.63267 |
# | scale_pos_weight                             1 |
# | subsample                              0.78655 |
# +------------------------------------------------+
#
# Trial train_xgb_dd946_00353 completed after 1 iterations at 2023-08-22 02:50:03. Total running time: 5min 8s
# +------------------------------------------------+
# | Trial train_xgb_dd946_00353 result             |
# +------------------------------------------------+
# | time_this_iter_s                       0.73951 |
# | time_total_s                           0.73951 |
# | training_iteration                           1 |
# | mean_f1                                0.02653 |
# +------------------------------------------------+
#
# Trial train_xgb_dd946_00354 started with configuration:
# +------------------------------------------------+
# | Trial train_xgb_dd946_00354 config             |
# +------------------------------------------------+
# | colsample_bytree                       0.97923 |
# | learning_rate                          0.00554 |
# | max_depth                                   75 |
# | min_child_weight                       8.71544 |
# | reg_alpha                              0.80249 |
# | reg_lambda                             0.65737 |
# | scale_pos_weight                         ratio |
# | subsample                              0.72484 |
# +------------------------------------------------+
#
# Trial train_xgb_dd946_00351 completed after 1 iterations at 2023-08-22 02:50:04. Total running time: 5min 9s
# +------------------------------------------------+
# ...
# | train_xgb_dd946_00429   TERMINATED           125        0.0245795       0.921869             0.276126              2.67506    0.107931       0.902917     1                         1           2.21913    0.0290621 |
# | train_xgb_dd946_00430   TERMINATED            25        0.0352349       0.521821             0.745645              2.34563    0.0373844      0.31809      ratio                     1           2.74784    0.206439  |
# | train_xgb_dd946_00431   TERMINATED            25        0.00339444      0.79987              0.340298              5.54614    0.0860113      0.880901     1                         1           1.56377    0.0549313 |
# | train_xgb_dd946_00432   TERMINATED            50        0.0522258       0.533309             0.771378              2.18871    0.0477763      0.694547     ratio                     1           2.15183    0.167498  |
# | train_xgb_dd946_00433   TERMINATED            25        0.00241993      0.793635             0.663752              9.72469    0.282673       0.68658      ratio                     1           2.06066    0.35553   |
# | train_xgb_dd946_00434   TERMINATED             5        0.0398729       0.388773             0.667374              2.44771    0.953327       0.440323     ratio                     1           0.785913   0.227535  |
# | train_xgb_dd946_00435   TERMINATED             5        0.0468363       0.622828             0.796517              5.82824    0.139933       0.884177     1                         1           1.02496    0.117783  |
# | train_xgb_dd946_00436   TERMINATED            75        0.00291547      0.751651             0.486936              7.66018    0.346169       0.66196      ratio                     1           1.59686    0.34262   |
# | train_xgb_dd946_00437   TERMINATED           125        0.0339042       0.997602             0.486583              8.22676    0.836224       0.121185     1                         1           1.36802    0.220444  |
# | train_xgb_dd946_00438   TERMINATED            25        0.0040528       0.727498             0.582728              4.16803    0.418737       0.657107     1                         1           1.42049    0.190858  |
# | train_xgb_dd946_00439   TERMINATED           125        0.00158425      0.945379             0.800007              2.76144    0.755348       0.967406     1                         1           2.29562    0.243874  |
# | train_xgb_dd946_00440   TERMINATED            75        0.00363134      0.96175              0.426057              5.10288    0.907816       0.206567     1                         1           1.32537    0.0964912 |
# | train_xgb_dd946_00441   TERMINATED            50        0.00156557      0.874474             0.785397              5.41055    0.732282       0.547748     1                         1           1.97336    0.219287  |
# | train_xgb_dd946_00442   TERMINATED             5        0.0236631       0.927151             0.453355              6.53906    0.533946       0.198366     ratio                     1           0.813406   0.366685  |
# | train_xgb_dd946_00443   TERMINATED             5        0.0920654       0.237886             0.805884              6.65237    0.651215       0.696889     1                         1           0.513619   0.15859   |
# | train_xgb_dd946_00444   TERMINATED           100        0.00530094      0.777609             0.671978              6.23677    0.161153       0.629038     1                         1           3.07989    0.0722611 |
# | train_xgb_dd946_00445   TERMINATED             5        0.0071742       0.657057             0.936544              5.52659    0.380388       0.705815     ratio                     1           2.76518    0.344872  |
# | train_xgb_dd946_00446   TERMINATED            25        0.0156236       0.24321              0.977769              5.90582    0.635531       0.0662541    ratio                     1           2.36728    0.22813   |
# | train_xgb_dd946_00447   TERMINATED           100        0.0169533       0.371242             0.590391              6.90257    0.57962        0.229736     1                         1           1.66117    0.0560976 |
# | train_xgb_dd946_00448   TERMINATED            25        0.00638459      0.466792             0.561455              2.92313    0.771391       0.858075     1                         1           2.24607    0.120574  |
# | train_xgb_dd946_00449   TERMINATED           100        0.00236774      0.567992             0.207391              8.93711    0.192235       0.963364     1                         1           0.916689   0.0204678 |
# | train_xgb_dd946_00450   TERMINATED            50        0.00163003      0.806611             0.413155              2.92883    0.393356       0.107388     1                         1           3.06005    0.115668  |
# | train_xgb_dd946_00451   TERMINATED            25        0.00234128      0.920595             0.66954               2.66935    0.54359        0.513732     ratio                     1           4.38118    0.353939  |
# | train_xgb_dd946_00452   TERMINATED           100        0.00216345      0.710603             0.378873              2.93639    0.115507       0.546423     1                         1           1.52245    0.082519  |
# | train_xgb_dd946_00453   TERMINATED           125        0.0289401       0.544836             0.806223              4.73872    0.712007       0.494669     1                         1           1.505      0.141612  |
# | train_xgb_dd946_00454   TERMINATED           125        0.0151466       0.81016              0.688837              3.48879    0.860147       0.982095     ratio                     1           2.5309     0.337596  |
# | train_xgb_dd946_00455   TERMINATED            75        0.00351954      0.230275             0.484878              3.77759    0.877422       0.503052     1                         1           0.458333   0.0607477 |
# | train_xgb_dd946_00456   TERMINATED             5        0.0847332       0.888693             0.772426              2.90369    0.00957821     0.132955     1                         1           1.20202    0.212687  |
# | train_xgb_dd946_00457   TERMINATED            25        0.0394074       0.599788             0.597631              8.24702    0.37037        0.190828     1                         1           1.18806    0.103837  |
# | train_xgb_dd946_00458   TERMINATED           125        0.00672707      0.348327             0.367179              4.12403    0.719279       0.0910633    1                         1           0.604752   0.0224159 |
# | train_xgb_dd946_00459   TERMINATED            25        0.00212871      0.86573              0.96469               4.97464    0.48306        0.221239     ratio                     1           3.46187    0.350117  |
# | train_xgb_dd946_00460   TERMINATED            25        0.0108888       0.818898             0.63276               5.67438    0.753387       0.0451917    ratio                     1           2.1852     0.350029  |
# | train_xgb_dd946_00461   TERMINATED           100        0.0171541       0.669748             0.219899              9.28116    0.695168       0.572834     1                         1           0.554036   0.019943  |
# | train_xgb_dd946_00462   TERMINATED             5        0.0055734       0.330123             0.64438               5.7238     0.0830304      0.397581     1                         1           0.638482   0.150745  |
# | train_xgb_dd946_00463   TERMINATED             5        0.0247435       0.57317              0.484533              7.41188    0.905713       0.942175     1                         1           0.674805   0.107271  |
# | train_xgb_dd946_00464   TERMINATED            75        0.0227323       0.430488             0.314098              3.4388     0.143858       0.47115      1                         1           0.769073   0.0406607 |
# | train_xgb_dd946_00465   TERMINATED             5        0.00903137      0.629519             0.381823              5.93802    0.145831       0.568369     ratio                     1           0.689436   0.274134  |
# | train_xgb_dd946_00466   TERMINATED            50        0.00339939      0.374502             0.235453              6.69925    0.461991       0.646854     1                         1           0.415492   0.0198582 |
# | train_xgb_dd946_00467   TERMINATED            75        0.00554679      0.650868             0.812205              9.09033    0.512715       0.650568     ratio                     1           3.58091    0.34098   |
# | train_xgb_dd946_00468   TERMINATED           125        0.00565575      0.36893              0.99243               9.47401    0.368125       0.540122     ratio                     1           2.51625    0.299606  |
# | train_xgb_dd946_00469   TERMINATED            75        0.0196685       0.471611             0.631317              4.11072    0.288448       0.593466     1                         1           2.29582    0.153846  |
# | train_xgb_dd946_00470   TERMINATED           125        0.0010008       0.477303             0.710793              9.21553    0.420764       0.660981     ratio                     1           2.22563    0.330425  |
# | train_xgb_dd946_00471   TERMINATED            50        0.00393405      0.867703             0.867653              2.7245     0.401287       0.22452      1                         1           2.91196    0.246506  |
# | train_xgb_dd946_00472   TERMINATED             5        0.0972236       0.593527             0.24567               7.75869    0.388515       0.325586     1                         1           0.40654    0.0793061 |
# | train_xgb_dd946_00473   TERMINATED           100        0.00706339      0.251493             0.386493              7.70365    0.421949       0.640726     ratio                     1           0.596563   0.307859  |
# | train_xgb_dd946_00474   TERMINATED            25        0.0685579       0.578995             0.848096              2.6043     0.287401       0.243501     ratio                     1           2.45996    0.282425  |
# | train_xgb_dd946_00475   TERMINATED            75        0.0120198       0.44262              0.425282              8.96686    0.715722       0.0386222    ratio                     1           1.04104    0.318241  |
# | train_xgb_dd946_00476   TERMINATED            75        0.0310582       0.730282             0.718275              8.52861    0.716075       0.552855     1                         1           1.43184    0.154006  |
# | train_xgb_dd946_00477   TERMINATED           100        0.0770841       0.299403             0.661542              4.14622    0.575895       0.832264     ratio                     1           1.0618     0.230703  |
# | train_xgb_dd946_00478   TERMINATED           100        0.00291047      0.237941             0.698448              7.38955    0.76003        0.477341     ratio                     1           0.831981   0.310465  |
# | train_xgb_dd946_00479   TERMINATED             5        0.0744941       0.487702             0.465954              4.70889    0.75412        0.768062     ratio                     1           0.660903   0.209586  |
# | train_xgb_dd946_00480   TERMINATED            50        0.0433067       0.871111             0.985296              5.13144    0.548614       0.779787     ratio                     1           3.29213    0.358655  |
# | train_xgb_dd946_00481   TERMINATED            25        0.0096412       0.70526              0.37795               9.07959    0.236589       0.996975     1                         1           0.913441   0.114478  |
# | train_xgb_dd946_00482   TERMINATED             5        0.0169735       0.399197             0.3077                4.31826    0.111798       0.0238677    1                         1           0.394997   0.0217984 |
# | train_xgb_dd946_00483   TERMINATED           100        0.0257153       0.719829             0.660212              4.30326    0.134295       0.795595     ratio                     1           2.17913    0.313811  |
# | train_xgb_dd946_00484   TERMINATED            25        0.0532743       0.656235             0.518926              9.81374    0.547164       0.314478     ratio                     1           1.74555    0.318031  |
# | train_xgb_dd946_00485   TERMINATED           100        0.0604724       0.573016             0.236233              2.65516    0.450369       0.848637     1                         1           0.865376   0.0823245 |
# | train_xgb_dd946_00486   TERMINATED           100        0.0162885       0.533626             0.493517              5.57988    0.925803       0.641242     ratio                     1           2.56567    0.321258  |
# | train_xgb_dd946_00487   TERMINATED           125        0.00969443      0.37611              0.407405              9.85589    0.584048       0.432641     ratio                     1           1.52275    0.282852  |
# | train_xgb_dd946_00488   TERMINATED             5        0.00224938      0.778745             0.390727              5.92688    0.813616       0.607615     1                         1           1.14544    0.0743322 |
# | train_xgb_dd946_00489   TERMINATED           100        0.0551148       0.24846              0.752231              3.17105    0.764368       0.509789     1                         1           1.41486    0.162281  |
# | train_xgb_dd946_00490   TERMINATED            25        0.0597769       0.466204             0.39471               8.47604    0.942447       0.0216525    1                         1           1.02766    0.0543478 |
# | train_xgb_dd946_00491   TERMINATED           125        0.00710212      0.439614             0.924921              5.99732    0.77071        0.926207     ratio                     1           2.36915    0.327493  |
# | train_xgb_dd946_00492   TERMINATED            50        0.0181675       0.289926             0.241633              9.22896    0.783897       0.53323      ratio                     1           0.864653   0.275337  |
# | train_xgb_dd946_00493   TERMINATED            50        0.0957743       0.314764             0.443215              2.42416    0.170654       0.767515     ratio                     1           0.995638   0.16444   |
# | train_xgb_dd946_00494   TERMINATED           100        0.0389429       0.844852             0.34309               6.47402    0.095001       0.255818     1                         1           1.12092    0.113856  |
# | train_xgb_dd946_00495   TERMINATED            50        0.0833348       0.531264             0.588059              5.6491     0.945782       0.435263     1                         1           0.987357   0.112676  |
# | train_xgb_dd946_00496   TERMINATED            50        0.00669474      0.551345             0.642363              8.4083     0.469451       0.402818     ratio                     1           1.55543    0.329656  |
# | train_xgb_dd946_00497   TERMINATED            75        0.00214773      0.856068             0.379902              9.26777    0.620423       0.65846      ratio                     1           1.45064    0.339855  |
# | train_xgb_dd946_00498   TERMINATED            25        0.0196495       0.307518             0.757157              5.81909    0.944529       0.829477     1                         1           0.736272   0.12684   |
# | train_xgb_dd946_00499   TERMINATED            25        0.0151965       0.463031             0.91087               6.95959    0.00683764     0.38795      ratio                     1           1.49631    0.295775  |
# +----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
#
# Best configuration: {'max_depth': 5, 'learning_rate': 0.001014842214576956, 'subsample': 0.812485400220675, 'colsample_bytree': 0.8413828771534, 'min_child_weight': 7.957627241204943, 'reg_alpha': 0.9572022104599709, 'reg_lambda': 0.7072443412811837, 'scale_pos_weight': 'ratio'}
# best f1: 0.37688984881209503
